# %%
i_price = int(input("Enter price(excl tax): "))
i_incl_tax = int(i_price * 1.10)
if i_incl_tax >= 2000:
    str_sheep='送料は無料です'
else:
    str_sheep='送料は350円です'
print(f'送料は{"無料" if i_incl_tax >= 2000 else "350円" }です\n送料込税込価格は{i_incl_tax}円です')
# Out:
# 送料は無料です
# 送料込税込価格は2145円です
