# %%
# -*- coding: utf-8 -*-
greetings = "Hello, There!"
my_name = "山田太郎"
my_age = 25
print(f'{greetings} My name is {my_name} and I am {my_age} years old.')
# Out:
# Hello, There! My name is 山田太郎 and I am 25 years old.
