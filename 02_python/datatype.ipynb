# %%
a = 10 
b = - 5 
c = 0
sum_result = a + b   # 10 + (-5) = 5 
product_result = a * b   # 10 * (-5) = -50
print( " a: " , a)
print( " b: " , b)
print( " c: " , c)
print( " 합계: " , sum_result)
print( " 곱: " , product_result)

division_result = a / 3
integer_division_result = a // 3

print( " 나누기 결과: " , division_result)
print( " 정수 나누기 결과: " , integer_division_result)
# Out:
#  a:  10
#  b:  -5
#  c:  0
#  합계:  5
#  곱:  -50
#  나누기 결과:  3.3333333333333335
#  정수 나누기 결과:  3

# %%
x = 3.14 
y = - 0.5 
z = 2.0
sum_result = x + y
product_result = x * y
print( " x: " , x)
print( " y: " , y)
print( " z: " , z)
print( " 합계: " , sum_result)
print( " 곱: " , product_result)
# Out:
#  x:  3.14
#  y:  -0.5
#  z:  2.0
#  합계:  2.64
#  곱:  -1.57

# %%
result = 0.1 + 0.2 
print( " 0.1 + 0.2 = " , result)
# Out:
#  0.1 + 0.2 =  0.30000000000000004

# %%
a = 10
b = float (a)
print( " a 의 형태: " , type (a))
print( " b 의 형태: " , type (b))
# Out:
#  a 의 형태:  <class 'int'>
#  b 의 형태:  <class 'float'>

# %%
x = 3.99
y = int (x)
print( " x 형식: " , type (x))
print( " y 의 형태: " , type (y))
print( " y 의 값: " , y)
# Out:
#  x 형식:  <class 'float'>
#  y 의 형태:  <class 'int'>
#  y 의 값:  3

# %%
num = 1.23e4 
print(num)
num = 1.23e-4 
print(num)
# Out:
# 12300.0
# 0.000123

# %%
c1 = 2 + 3j 
c2 = - 1 + 0.5j
sum_result = c1 + c2
product_result = c1 * c2
print( " c1: " , c1)
print( " c2: " , c2)
print( " 합계: " , sum_result)
print( " 곱: " , product_result)
# Out:
#  c1:  (2+3j)
#  c2:  (-1+0.5j)
#  합계:  (1+3.5j)
#  곱:  (-3.5-2j)

# %%
text1 = "「'」はシングルクォートです。"
text2 = '「"」はダブルクォートです。'
print(text1)
print(text2)
# Out:
# 「'」はシングルクォートです。
# 「"」はダブルクォートです。

# %%
text1 = " Hello " 
text2 = " World " 
result = text1 + " "  + text2 
print(result)
text = " Hi! " 
print(text * 3 )
length = len("Hello, World!")  # 13
print("文字列の長さ:", length)
# Out:
#  Hello   World
#  Hi!  Hi!  Hi!
# 文字列の長さ: 13

# %%
text = "Python"
print(text.upper())  # 'PYTHON'
print(text.lower())
text = "Hello, World"
print(text.replace("World", "Python"))
text = "  Hello, World!  "
print(text.strip())
text = "Hello, World"
print(text.find("World"))
# Out:
# PYTHON
# python
# Hello, Python
# Hello, World!
# 7

# %%
print("エスケープを使うと、「\'」シングルクォートと「\"」ダブルクォートを混在させたり、\n改行や\tタブを入れたりと多彩な表現が可能です")
# Out:
# エスケープを使うと、「'」シングルクォートと「"」ダブルクォートを混在させたり、
# 改行や	タブを入れたりと多彩な表現が可能です

# %%
message = '''A様
いつもお世話になっております。Bです。
先日はお越しくださりありがとうございました。
またのご来店をお待ちしております。'''

print(message)
# Out:
# A様
# いつもお世話になっております。Bです。
# 先日はお越しくださりありがとうございました。
# またのご来店をお待ちしております。

# %%
price = "100"
print("税込価格は", price * 1.1, "円です")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 price = "100"
# ----> 2 print("税込価格は", price * 1.1, "円です")
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
num = 100
num_str = str(num)
print("num_str の型:", type(num_str))
print("num_str の値:", num_str)
str_value = "250"
int_value = int(str_value)
print("int_value の型:", type(int_value))
print("int_value の値:", int_value)
# Out:
# num_str の型: <class 'str'>
# num_str の値: 100
# int_value の型: <class 'int'>
# int_value の値: 250

# %%
name = input("名前を入力してください: ")
print("こんにちは、" + name + "さん!")
# Out:
# こんにちは、aaaaさん!

# %%
num = int(input("数値を入力してください: "))
result = num + 10
print("入力した数値に10を足すと", result, "です")
# Out:
# 入力した数値に10を足すと 6697 です

# %%
a = 5
b = 10
result = a < b
equal_result = a == b
print("a < b:", result)
print("a == b:", equal_result)
# Out:
# a < b: True
# a == b: False

# %%
print(bool(0))
print(bool(1))
print(bool(""))
print(bool("Hello"))
# Out:
# False
# True
# False
# True

# %%
print(True + True)
print(True * 10)
print(False + 5)
# Out:
# 2
# 10
# 5

# %%
name = "ジョン"
age = 30
print(f"私の名前は{name}です。私は{age}歳です。")
# Out:
# 私の名前はジョンです。私は30歳です。

# %%
a = 5
b = 10
print(f"{a}足す{b}は{a + b}です。")
# Out:
# 5足す10は15です。

# %%
# 小数点以下の桁数
pi = 3.14159
print(f"小数点以下の桁数: {pi:.2f}") # 2桁に指定

# カンマ区切り
large_number = 1234567890
print(f"カンマ区切り: {large_number:,}")

# 文字列の出力幅
name = "Alice"
print(f"文字列の幅「{name:10}」")  # 10文字分の幅で表示

# ゼロ埋め
num = 42
print(f"ゼロ埋め: {num:05}")  # 5桁で表示し、足りない部分はゼロで埋める

# パーセント表示
accuracy = 0.856
print(f"パーセント表示: {accuracy:.1%}")

# 揃え
name = "Alice"
print(f"左揃え　「{name:<10}」")  # 左揃えで10文字幅
print(f"右揃え　「{name:>10}」")  # 右揃えで10文字幅
print(f"中央揃え「{name:^10}」")  # 中央揃えで10文字幅

# 日時のフォーマット
from datetime import datetime
now = datetime.now()
print(f"現在日時: {now:%Y-%m-%d %H:%M:%S}")
# Out:
# 小数点以下の桁数: 3.14
# カンマ区切り: 1,234,567,890
# 文字列の幅「Alice     」
# ゼロ埋め: 00042
# パーセント表示: 85.6%
# 左揃え　「Alice     」
# 右揃え　「     Alice」
# 中央揃え「  Alice   」
# 現在日時: 2026-04-13 10:22:05

# %%
value = None  # 変数を初期化
if value is None:
    print("まだ値が設定されていません")
# Out:
# まだ値が設定されていません

# %%
def greet():
    print("Hello!")
result = greet()
print(result)
# Out:
# Hello!
# None

# %%
data = None
if data is None:
    print("データがありません")
# Out:
# データがありません
