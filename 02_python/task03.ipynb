# %%
seed = int(input("Enter amount of seed(yen): "))
apy = float(input("Enter APY(%): "))
print(f"Initial seed: {seed} yen, APY: {apy}%")
for i in  range ( 1 , 11 , 1 ) :
    seed = seed * ( 1 + (apy / 100 ) )
    print ( f"Compound after {i:02d} year(s) : {seed:.2f} yen" )
# Out:
# Initial seed: 6000 yen, APY: 3.21%
# Compound after 01 year(s) : 6192.60 yen
# Compound after 02 year(s) : 6391.38 yen
# Compound after 03 year(s) : 6596.55 yen
# Compound after 04 year(s) : 6808.29 yen
# Compound after 05 year(s) : 7026.84 yen
# Compound after 06 year(s) : 7252.40 yen
# Compound after 07 year(s) : 7485.20 yen
# Compound after 08 year(s) : 7725.48 yen
# Compound after 09 year(s) : 7973.47 yen
# Compound after 10 year(s) : 8229.42 yen
