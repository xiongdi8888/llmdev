# %%
import  math
print(math.sqrt(25))
print(math.exp(1))
print(math.pi)
# Out:
# 5.0
# 2.718281828459045
# 3.141592653589793

# %%
import datetime
now = datetime.datetime.now()
print(now)
birthday = datetime.datetime(1995, 5, 17)
print(birthday)
date1 = datetime.datetime(2023, 1, 1)
date2 = datetime.datetime(2024, 1, 1)
diff = date2 - date1
print(diff.days)
# Out:
# 2026-04-14 16:36:22.194803
# 1995-05-17 00:00:00
# 365

# %%
import random
print(random.randint(1, 10))

my_list = [1, 2, 3, 4, 5]
random.shuffle(my_list)
print(my_list)
print(random.choice(my_list))
# Out:
# 6
# [5, 2, 1, 4, 3]
# 1

# %%
import os
#print(os.getcwd()) #-> Security issue may occur: OS guess, If working directory is under user home(~), significant issue(SSO account name or real name) / Due to techacademy specified rule - 'YOU NEED TO CONFIGURE YOUR REPOSITORY AS PUBLIC REPOSITORY'
#os.mkdir("new_folder")
print(os.path.exists("example.txt"))
# Out:
# False

# %%
import urllib.request

# URLを指定してデータを取得
url = "https://techacademy.jp"
response = urllib.request.urlopen(url)

# HTMLデータを読み込み、UTF-8文字列にデコード
html = response.read().decode("utf-8")
print(html[:500])
# Out:
# <!DOCTYPE html><html  lang="ja" data-theme="techacademy" data-capo=""><head><meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <title>テックアカデミー</title>
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# <script src="https://www.googletagmanager.com/gtag/js?id=AW-1006744060" async data-hid="92ebc66"></script>
# <script src="//static.criteo.net/js/ld/ld.js" async type="text/javascrip
