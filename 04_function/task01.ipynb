# %%
#ユーザー名バリデーション課題完了
def validate_username(user_name):
     if len(user_name) < 5 or len(user_name) > 15:
         print("エラー: ユーザー名は5文字以上15文字以内で入力してください")
         return False
     elif ' ' in user_name:
         print("エラー: ユーザー名に空白を含めることはできません")
         return False
     elif not user_name.isalnum():
         print("エラー: ユーザー名は英数字のみ使用できます")
         return False
     else:
         return True

user_name = input("input words(alpha only): ")
if validate_username(user_name):
     print("ユーザー名は有効です")
else:
     print("不正なユーザー名です")
# Out:
# エラー: ユーザー名に空白を含めることはできません
# 不正なユーザー名です
